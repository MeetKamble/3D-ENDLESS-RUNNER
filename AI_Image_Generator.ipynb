# %% [markdown]
# <a href="https://colab.research.google.com/github/MeetKamble/3D-ENDLESS-RUNNER/blob/main/AI_Image_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118
# Out:
# ...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...

# %%
#@title from huggingface_hub import login login(token='your_hugging_face_token')

from huggingface_hub import login
login(token='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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from diffusers import StableDiffusionPipeline
import torch

#specify the model ID for stable diffusion
model_id = "runwayml/stable-diffusion-v1-5"

#load the stable diffusion model pipeline
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

# Define a function to generate images
def generate_image(prompt):
    with torch.autocast("cuda"):
        image = pipe(prompt).images[0]
    image_path = "/content/generated_image.png"
    image.save(image_path)
    return image_path

# Test the function
prompt = "Man eating food"
image_path = generate_image(prompt)
image_path
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# '/content/generated_image.png'

# %%
from PIL import Image

image = Image.open(image_path)
image.show()
